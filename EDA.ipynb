# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import os

# The path printed from your download script
path = "/home/codespace/.cache/kagglehub/datasets/ahmeduzaki/nobel-prize-winners-dataset-1901-2025/versions/1"

# See what's actually inside the folder
print(os.listdir(path))
# Out:
# ['nobel_prizes_1901-2025_cleaned.csv']

# %%
df = pd.read_csv(os.path.join(path, 'nobel_prizes_1901-2025_cleaned.csv'))

# %%
print("Descriptive statistics of the dataset:")
df.describe()
# Out:
# Descriptive statistics of the dataset:
#         award_year  prize_amount  prize_amount_adjusted  laureate_id  \
# count   995.000000  9.950000e+02           9.950000e+02   995.000000
# mean   1974.826131  3.959410e+06           8.030975e+06   518.186935
# std      35.009814  4.275932e+06           4.101196e+06   307.864180
# min    1901.000000  1.149350e+05           3.006134e+06     1.000000
# 25%    1950.000000  1.727600e+05           3.923237e+06   249.500000
# 50%    1980.000000  8.800000e+05           6.845037e+06   505.000000
# 75%    2004.000000  9.000000e+06           1.160359e+07   780.500000
# max    2025.000000  1.100000e+07           1.554754e+07  1060.000000
#
#           portion  sort_order  birth_latitude  birth_longitude  \
# count  995.000000  995.000000      734.000000       734.000000
# mean     0.611390    1.510553       42.630474       -12.060271
# std      0.292668    0.702567       17.133752        59.247436
# min      0.250000    1.000000      -41.298971      -157.855682
# 25%      0.333333    1.000000       40.676379       -73.949819
# 50%      0.500000    1.000000       46.836465         2.355954
# 75%      1.000000    2.000000       51.510235        14.782150
# max      1.000000    3.000000       64.145844       176.190327
#
#        death_latitude  death_longitude  affiliation_latitude  \
# count      534.000000       534.000000            542.000000
# mean        43.620160       -24.910854             44.085730
# std         14.442423        56.261828             10.968079
# min        -37.797306      -157.855682            -37.797306
# 25%         40.359783       -74.011300             40.014316
# 50%         46.999319         0.135092             42.444089
# 75%         51.532098         9.913113             51.510235
# max         69.649739       151.216461             63.430515
#
#        affiliation_longitude   is_shared  winners_per_year  \
# count             542.000000  995.000000        995.000000
# mean              -37.420338    0.655276          9.297487
# std                58.555238    0.475517          2.898335
# min              -123.120129    0.000000          1.000000
# 25%               -78.550003    0.000000          7.000000
# 50%                -7.703068    1.000000         10.000000
# 75%                 7.821994    1.000000         12.000000
# max               149.130915    1.000000         14.000000
#
#        winners_per_category  is_repeat_winner  country_winner_rank
# count            995.000000        995.000000           751.000000
# mean             184.877387          0.005025            40.161119
# std               53.419236          0.070745            52.565940
# min               99.000000          0.000000             1.000000
# 25%              122.000000          0.000000             5.000000
# 50%              200.000000          0.000000            15.000000
# 75%              230.000000          0.000000            53.000000
# max              232.000000          1.000000           207.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   award_year             995 non-null    int64
#  1   date_awarded           995 non-null    str
#  2   prize_amount           995 non-null    int64
#  3   prize_amount_adjusted  995 non-null    int64
#  4   laureate_id            995 non-null    float64
#  5   known_name             995 non-null    str
#  6   full_name              995 non-null    str
#  7   sex                    752 non-null    str
#  8   portion                995 non-null    float64
#  9   sort_order             995 non-null    float64
#  10  motivation             995 non-null    str
#  11  category               995 non-null    str
#  12  birth_date             752 non-null    str
#  13  birth_city             750 non-null    str
#  14  birth_country          751 non-null    str
#  15  birth_latitude         734 non-null    float64
#  16  birth_longitude        734 non-null    float64
#  17  death_date             563 non-null    str
#  18  death_city             548 non-null    str
#  19  death_country          554 non-null    str
#  20  death_latitude         534 non-null    float64
#  21  death_longitude        534 non-null    float64
#  22  affiliation_name       553 non-null    str
#  23  affiliation_city       551 non-null    str
#  24  affiliation_country    553 non-null    str
#  25  affiliation_latitude   542 non-null    float64
#  26  affiliation_longitude  542 non-null    float64
#  27  wikipedia_url          752 non-null    str
#  28  is_shared              995 non-null    int64
#  29  winners_per_year       995 non-null    int64
#  30  winners_per_category   995 non-null    int64
#  31  is_repeat_winner       995 non-null    int64
#  32  country_winner_rank    751 non-null    float64
# dtypes: float64(10), int64(7), str(16)
# memory usage: 256.7 KB
